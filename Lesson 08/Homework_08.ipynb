# %% [markdown]
# ### Домашнее задание
#
# #### 1. Если мы рассчитали 95% доверительный интервал для среднего значения, то какие из следующих утверждений являются верными?
#
# Выберите несколько вариантов и попытайтесь объяснить свой выбор:
#
# 1) Если многократно повторять эксперимент, то 95 % выборочных средних значений будут принадлежать рассчитанному нами доверительному интервалу.
#
# 2) Мы можем быть на 95% уверены, что среднее значение в генеральной совокупности принадлежит рассчитанному доверительному интервалу.
#
# 3) Если многократно повторять эксперимент, для каждой выборки рассчитывать свой доверительный интервал, то в 95 % случаев истинное среднее будет находиться внутри доверительного интервала.
#
# 4) Среднее значение в генеральной совокупности точно превышает нижнюю границу 95% доверительного интервала.
#
# 5) Среднее значение в генеральной совокупности точно принадлежит рассчитанному доверительному интервалу.

# %% [markdown]
# **Ответ**

# %% [markdown]
# 1. Можно считать истинным при условии случайных выборок, того, что распределение имеет нормальную или близкую к нормальной форму и то, что изначальный интервал был посчитан для всей генеральной совокупности.
# 2. Если перефразировать, что с вероятностью 95% у нас среднее значение генеральной совокупности будет лежать в диапазоне определнной границами этого интервала, тогда будет верно.
# В текущей формулировке я считаю неверным.
# 3. Очень неаккуратное определение. Т.к. мы имеем дело с вероятностью, конкретный процент может быть только при условии проведения бесконечного количества экспериментов. И опять же, если переформклировать насчет вероятности в 95%, то с моей точки зрения утверждение будет ближе к истинному.
# 4.  Нет. т.к. мы работаем с вероятностями, а она не 100%.
# 5.  Нет. т.к. мы работаем с вероятностями, а она не 100%

# %% [markdown]
# #### 2. Если мы увеличиваем объем выборки в два раза (при условии, что показатель стандартного отклонения остается неизменным), то 95% доверительный интервал
#
# Выберите один вариант из списка
#
# 1) стал более узким
# 2) возможны оба варианта
# 3) стал более широким

# %% [markdown]
# **Ответ**

# %% [markdown]
# Доверительный интервал стал более узким.
# Конкретная величина должна высчитываться, но в общем случае она обратно пропорциональна корню квадратному из объема выборки.

# %% [markdown]
# #### 3. В центре 95% доверительного интервала, рассчитанного по выборочным значениям, находится:
#
# Выберите один вариант из списка
#
# 1) Значение стандартной ошибки среднего
# 2) Выборочное среднее значение
# 3) Среднее значение генеральной совокупности

# %% [markdown]
# **Ответ**

# %% [markdown]
# Среднее значение по данной выборке для которой рассчитывался интервал.
# Ответ 2)

# %% [markdown]
# #### 4. Часто на практике нулевая гипотеза отклоняется, и различия считаются статистически достоверными, если p < 0,05. Однако часто в статистике используется более жесткий критерий достоверности различий, например, при условии, что p < 0,01. Значение p-уровня значимости, которое выбирается, в качестве порога обозначается буквой α (альфа). Например, если исследователь решил, что α = 0,05, то и нулевая гипотеза будет отклоняться при условии, что p < 0,05.
#
# #### Если в определенной ситуации весьма рискованно отклонить нулевую гипотезу, когда она на самом деле верна, то лучше использовать показатель α равный
#
# Выберите один вариант из списка
#
# 1) 0,1
# 2) 0,001
# 3) 0,05
# 4) 0,5

# %% [markdown]
# **Ответ**

# %% [markdown]
# В данной ситуации чем ниже величина p тем больще вероятность, что нулевая гипотеза не будет отвергнута.
# Т.е. нужно выбрать минимальный порог из указанных.
# это велничина 2) 0,001

# %% [markdown]
# ------------

# %% [markdown]
# #### 5. Данные некоторого исследования сообщают нам, что средний рост детей в 14 лет составляет 166 сантиметров. Однако это лишь выборочная оценка, и исследователи рассчитали 95% доверительный интервал, который составил [160, 172]. Укажите верные утверждения:
#
# Выберите несколько вариантов и попытайтесь объяснить свой выбор:
#
# 1) У нас достаточно оснований отклонить нулевую гипотезу, что среднее в генеральной совокупности равняется 173
# 2) Вероятность того, что истинное среднее значение больше 172, составляет 0,01
# 3) У нас достаточно оснований отклонить нулевую гипотезу, что среднее в генеральной совокупности равняется 158.
# 4) Доверительный интервал не может иметь такие границы, т. к. выборочное стандартное отклонение равняется 10, следовательно доверительный интервал должен быть значительно шире.

# %% [markdown]
# **Ответ**

# %% [markdown]
# 1. Недостаточно данных, т.к. не указан порог значимости.
# Если принять, что величина порога p=0.05 на основании величины указанного доверительного интервала, тогда можно принять, что утверждение 1 верное.

# %% [markdown]
# 2. Если считать респределение нормальным и симметричным, то за границами 95% интервала содержится 5% значений. Т.к. считаем распределение симметричным, то можем считать, что дальше правой границы содержится 2,5% значений или вероятность 0,025.

# %% [markdown]
# 3. Не указан статистический уровень значимости.
# Если исходить из рассчитанного диапазона доверительного интервала, то можно принять p=0,05
# Значение 158 лежит за границами этого интервала, следовательно нулевая гипотеза может быть отвергнута.

# %% [markdown]
# 4. Ввиду отсутсвия данных о величине выборки, не уверен, что можно решить данную задачу однозначно.
# Стандартное отклонение 10 обеспечивается при заданном доверительном интервале при размере выборки приблизительно 13 человек.
# Т.е. в зависимости от размера выборки данное выражение может быть как истинным так и ложным.
# Исходя из гипотезы о том, что распределение нормально, можно попробовать узнать текущую величину выборочного стандартного отклонения.

# %%
from scipy import stats

# %%
#Для t-распределения границы доверительного интервала
t1 = stats.t.ppf(alpha / 2, df=n - 1)
t2 = stats.t.ppf(1 - alpha / 2, df=n - 1)

# %%
t1, t2
# Out:
# (-1.962341461133449, 1.9623414611334487)

# %% [markdown]
# Среднеквадратичное отклонение для распределения по нашей выборке:

# %% [markdown]
# 1.96*sigma = 6 =>

# %%
sigma = -6/t1
sigma
# Out:
# 3.057571844063468

# %% [markdown]
# т.к. область двустороняя то граница определяется:
# $\Omega_\alpha = (-\infty, t_{\alpha/2}) \cup (t_{1 - \alpha/2}, \infty)$
# где общая формула для t критерия
# $$t = \dfrac{\overline{X} - \mu}{\sigma_X / \sqrt{n}}$$
# или на выходе:
# $$P \left( \overline{X} + t_{\alpha / 2, \: n - 1} \cdot \dfrac{\sigma_X}{\sqrt{n}} \leq \mu \leq \overline{X} + t_{1 - \alpha / 2, \: n - 1} \cdot \dfrac{\sigma_X}{\sqrt{n}} \right) = p$$
# Для дальнейшего расчета нуждно задваться показателями размера выборки.
# Ориентировочный расчет для заданного среднеквадратичного отклонения приведен выше, в ответе к вопросу 4.

# %% [markdown]
# -----------

# %% [markdown]
# #### 6. Предположим, нулевой гипотезой вашего исследования являлось предположение, что конверсия в генеральной совокупности равняется 0.4. Вы получили p = 0,12 и не смогли отклонить нулевую гипотезу. Однако позже выяснилось, что конверсия в генеральной совокупности действиетльно равна 0.4. Как можно оценить результаты?
#
#
# Какой вариант корректный по вашему мнению и почему?
# 1) Вы не совершали ни ошибку первого рода, ни ошибку второго рода.
# 2) Вы совершили ошибку первого рода
# 3) Вы совершили ошибку второго рода

# %% [markdown]
# **Ответ**

# %% [markdown]
# Ошибка не была совершена т.к. нулевая гипотеза не была отклонена.
# Статистический анализ привел к совершенно правильному результату, что первая гипотеза не была принята и нулевая гипотеза осталась актуальной.
